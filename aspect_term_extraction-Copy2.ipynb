# %%
import xml.etree.ElementTree as ET
import nltk

def get_list(path):
    tree=ET.parse(path)
    root = tree.getroot()
    text_list = []
    id_list=[]
    new_list=[]
    sentences_list=[]
    opinion_list = []
    for review in root.findall('sentence'):
        print(review)
        text_string=""
        opinion_inner_list=[]
        #or sent in review.findall('./sentences/sentence'):
        #print(sent)
        ids=review.attrib['id']
        print(ids)
        id_list.append(ids)
        text_string= text_string+ " "+ review.find('text').text
        new_list.append(ids)
        sentences_list.append(review.find('text').text)
#             new_list.append(sent.find('text').text)
        
#         text_list.append(text_string)
#         for opinion in review.findall('./Opinions/Opinion'):
#             opinion_dict = {
#                 opinion.get('category').replace('#','_'): opinion.get('polarity')
#             }
#             opinion_inner_list.append(opinion_dict)
#         opinion_list.append(opinion_inner_list)
    return text_list,opinion_list,new_list,sentences_list
train_text_list,train_opinion_list,new_list,sentences_list = get_list("/home/vibha/Laptops_Train.xml")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-7c0b9c8d4615> in <module>()
#      32 #         opinion_list.append(opinion_inner_list)
#      33     return text_list,opinion_list,new_list,sentences_list
# ---> 34 train_text_list,train_opinion_list,new_list,sentences_list = get_list("/home/vibha/Laptops_Train.xml")
#
# <ipython-input-13-7c0b9c8d4615> in get_list(path)
#       3
#       4 def get_list(path):
# ----> 5     tree=ET.parse(path)
#       6     root = tree.getroot()
#       7     text_list = []
#
# /usr/lib/python3.4/xml/etree/ElementTree.py in parse(source, parser)
#    1185     """
#    1186     tree = ElementTree()
# -> 1187     tree.parse(source, parser)
#    1188     return tree
#    1189
#
# /usr/lib/python3.4/xml/etree/ElementTree.py in parse(self, source, parser)
#     585         close_source = False
# ...

# %%
import xml.etree.ElementTree as ET
import nltk

def get_list(path):
    tree=ET.parse(path)
    root = tree.getroot()
    text_list = []
    id_list=[]
    new_list=[]
    sentences_list=[]
    opinion_list = []
    for review in root.findall('sentence'):
        print(review)
        text_string=""
        opinion_inner_list=[]
        #or sent in review.findall('./sentences/sentence'):
        #print(sent)
        ids=review.attrib['id']
        print(ids)
        id_list.append(ids)
        text_string= text_string+ " "+ review.find('text').text
        new_list.append(ids)
        sentences_list.append(review.find('text').text)
#             new_list.append(sent.find('text').text)
        
#         text_list.append(text_string)
#         for opinion in review.findall('./Opinions/Opinion'):
#             opinion_dict = {
#                 opinion.get('category').replace('#','_'): opinion.get('polarity')
#             }
#             opinion_inner_list.append(opinion_dict)
#         opinion_list.append(opinion_inner_list)
    return text_list,opinion_list,new_list,sentences_list
train_text_list,train_opinion_list,new_list,sentences_list = get_list("/home/ayushi/Downloads/stanford-corenlp-full-2018-10-05/Laptops_Train.xml")
# Out:
# <Element 'sentence' at 0x7fb177fcbb88>
# 2339
# <Element 'sentence' at 0x7fb177fcb638>
# 812
# <Element 'sentence' at 0x7fb177fcbe08>
# 1316
# <Element 'sentence' at 0x7fb177fe8048>
# 2328
# <Element 'sentence' at 0x7fb177fe80e8>
# 2193
# <Element 'sentence' at 0x7fb177fe8188>
# 2005
# <Element 'sentence' at 0x7fb177fe83b8>
# 2789
# <Element 'sentence' at 0x7fb177fe84f8>
# 425
# <Element 'sentence' at 0x7fb177fe8598>
# 76
# <Element 'sentence' at 0x7fb177fe87c8>
# 747
# <Element 'sentence' at 0x7fb177fe8868>
# 80
# <Element 'sentence' at 0x7fb177fe89a8>
# 796
# <Element 'sentence' at 0x7fb177fe8a48>
# 917
# <Element 'sentence' at 0x7fb177fe8c78>
# 1788
# <Element 'sentence' at 0x7fb177fe8d18>
# 338
# <Element 'sentence' at 0x7fb177fe8ef8>
# 1630
# <Element 'sentence' at 0x7fb177fe5098>
# 38
# <Element 'sentence' at 0x7fb177fe5228>
# 337
# <Element 'sentence' at 0x7fb177fe5458>
# 1505
# <Element 'sentence' at 0x7fb177fe54f8>
# 263
# <Element 'sentence' at 0x7fb177fe5598>
# 1227
# ...

# %%
sentences_list
# Out:
# ['I charge it at night and skip taking the cord with me because of the good battery life.',
#  'I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.',
#  'The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.',
#  'I investigated netbooks and saw the Toshiba NB305-N410BL.',
#  'The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.',
#  'it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.',
#  'Easy to start up and does not overheat as much as other laptops.',
#  'Sad very SAD.',
# ...

# %%
contractions = {
"ain't": "am not / are not",
"aren't": "are not / am not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had / he would",
"he'd've": "he would have",
"he'll": "he shall / he will",
"he'll've": "he shall have / he will have",
"he's": "he has / he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how has / how is",
"i'd": "I had / I would",
"i'd've": "I would have",
"i'll": "I shall / I will",
"i'll've": "I shall have / I will have",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it had / it would",
"it'd've": "it would have",
"it'll": "it shall / it will",
"it'll've": "it shall have / it will have",
"it's": "it has / it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had / she would",
"she'd've": "she would have",
"she'll": "she shall / she will",
"she'll've": "she shall have / she will have",
"she's": "she has / she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as / so is",
"that'd": "that would / that had",
"that'd've": "that would have",
"that's": "that has / that is",
"there'd": "there had / there would",
"there'd've": "there would have",
"there's": "there has / there is",
"they'd": "they had / they would",
"they'd've": "they would have",
"they'll": "they shall / they will",
"they'll've": "they shall have / they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had / we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what shall / what will",
"what'll've": "what shall have / what will have",
"what're": "what are",
"what's": "what has / what is",
"what've": "what have",
"when's": "when has / when is",
"when've": "when have",
"where'd": "where did",
"where's": "where has / where is",
"where've": "where have",
"who'll": "who shall / who will",
"who'll've": "who shall have / who will have",
"who's": "who has / who is",
"who've": "who have",
"why's": "why has / why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had / you would",
"you'd've": "you would have",
"you'll": "you shall / you will",
"you'll've": "you shall have / you will have",
"you're": "you are",
"you've": "you have",
"here's":"here is"
}

# %%
#text="What's the best way to ensure this?"
from nltk.corpus import stopwords
a=[]
for i in sentences_list:
    for word in i.split():
        if (word.lower() in contractions):
            i = i.replace(word,contractions[word.lower()])
            
    a.append(i)
for i in a:
    print(i)
new_list=a
# Out:
# I charge it at night and skip taking the cord with me because of the good battery life.
# I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.
# The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.
# I investigated netbooks and saw the Toshiba NB305-N410BL.
# The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.
# it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.
# Easy to start up and does not overheat as much as other laptops.
# Sad very SAD.
# I even got my teenage son one, because of the features that it offers, like, iChat, Photobooth, garage band and more!
# ...

# %%
# li=[]
# ls=[]
# from nltk.corpus import stopwords
# sw=stopwords.words('english')
# for i in new_list:
#     li=[]
#     i=(i.replace(".",""))
#     i=(i.replace(",",""))
#     i=i.split(" ")
#     for word in i:
#         if word not in sw:
#             li.append(word)
#     ls.append(li)

# %%
new_list
# Out:
# ['I charge it at night and skip taking the cord with me because of the good battery life.',
#  'I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.',
#  'The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.',
#  'I investigated netbooks and saw the Toshiba NB305-N410BL.',
#  'The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.',
#  'it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.',
#  'Easy to start up and does not overheat as much as other laptops.',
#  'Sad very SAD.',
# ...

# %%
import re
import pandas as pd
import nltk
from nltk import word_tokenize
print(a)
# Out:
# ['I charge it at night and skip taking the cord with me because of the good battery life.', 'I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.', 'The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.', 'I investigated netbooks and saw the Toshiba NB305-N410BL.', 'The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.', 'it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.', 'Easy to start up and does not overheat as much as other laptops.', 'Sad very SAD.', 'I even got my teenage son one, because of the features that it offers, like, iChat, Photobooth, garage band and more!', 'Needles
# ...

# %%
for i in a[:30]:
    
    sen=i
    sen = [re.sub(r"[^a-zA-Z0-9]+", ' ', k) for k in sen.split("\n")]
    sen2=sen
    print(sen2)
    import os
    p=os.popen("echo '"+sen2[0]+"'~/stanford-parser-2012-11-12/stanfordtemp.txt")
    print(p)
    parser_out = os.popen("~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt")
    print(parser_out)
    
    for relation in parser_out:
        
        print(relation)
        #tr+=relation
# Out:
# ['I charge it at night and skip taking the cord with me because of the good battery life ']
# ...
# (ROOT
#
#   (S
#
#     (NP (JJS Most) (NN everything))
#
#     (VP (VBZ is)
#
#       (ADJP (JJ fine)
#
#         (PP (IN with)
#
#           (NP (DT this) (NN machine) (NN speed) (NN capacity))))
#
#       (S
#
#         (VP (VB build))))))
#
#
#
# amod(everything-2, Most-1)
#
# nsubj(fine-4, everything-2)
#
# cop(fine-4, is-3)
#
# root(ROOT-0, fine-4)
#
# det(capacity-9, this-6)
#
# nn(capacity-9, machine-7)
#
# nn(capacity-9, speed-8)
#
# prep_with(fine-4, capacity-9)
#
# ccomp(fine-4, build-10)
#
#
#
# ['I bought a HP Pavilion DV4 1222nr laptop and have had so many problems with the computer ']
# ...
# (ROOT
#
#   (S
#
#     (NP (JJS Most) (NN everything))
#
#     (VP (VBZ is)
#
#       (ADJP (JJ fine)
#
#         (PP (IN with)
#
#           (NP (DT this) (NN machine) (NN speed) (NN capacity))))
#
#       (S
#
#         (VP (VB build))))))
#
#
#
# amod(everything-2, Most-1)
#
# ...

# %%
head_word=['I',
 'laptop',
 'problems',
 'computer',
 'it',
 'night',
 'cord',
 'me',
 'life',
 'guy',
 'center',
 'exchange',
 'concern',
 'team',
 'shop',
 'netbook',
 'netbooks',
 'NB305-N410BL',
 'day',
 'presentation',
 'seminar',
 'lots',
 'conference',
 'town',
 'people',
 'time',
 'etc.',
 'projector',
 'quality',
 'GUI',
 'applications',
 'laptops',
 'one',
 'features',
 'more',
 'iChat',
 'Photobooth',
 'band',
 'PC',
 'phone',
 'they',
 'nothing',
 'problem',
 'thing',
 'dark',
 'light',
 'money',
 'while',
 'Fund',
 'disappointment',
 'model',
 'ones',
 'line',
 'processor',
 'cards',
 'trade-off',
 'you',
 'hours',
 'screen',
 'battery',
 'MacBooks',
 'enclosure',
 'edge',
 'seal',
 'con',
 'area',
 'mouse',
 'gaming',
 'work',
 'They',
 'place',
 'Toshiba',
 'repair',
 'this',
 'advantage',
 'company',
 'commercials',
 'there',
 'things',
 'Apple',
 'way',
 'suite',
 'software',
 'speed',
 'side',
 'Windows',
 'expectation',
 'That',
 'devices',
 'game',
 'here',
 'keyboard',
 'issue']

# %%
from stanfordcorenlp import StanfordCoreNLP

nlp = StanfordCoreNLP(r'/home/vibha/stanford-corenlp-full-2018-10-05')

# %%
head_word=[]

# %%
from nltk.tree import Tree


def find_noun_phrases(tree):
    return [subtree for subtree in tree.subtrees(lambda t: t.label()=='NP')]

def find_head_of_np(np):
    noun_tags = ['NN', 'NNS', 'NNP', 'NNPS']
    top_level_trees = [np[i] for i in range(len(np)) if type(np[i]) is Tree]
    ## search for a top-level noun
    top_level_nouns = [t for t in top_level_trees if t.label() in noun_tags]
    if len(top_level_nouns) > 0:
        ## if you find some, pick the rightmost one, just 'cause
        return top_level_nouns[-1][0]
    else:
        ## search for a top-level np
        top_level_nps = [t for t in top_level_trees if t.label()=='NP']
        if len(top_level_nps) > 0:
            ## if you find some, pick the head of the rightmost one, just 'cause
            return find_head_of_np(top_level_nps[-1])
        else:
            ## search for any noun
            nouns = [p[0] for p in np.pos() if p[1] in noun_tags]
            if len(nouns) > 0:
                ## if you find some, pick the rightmost one, just 'cause
                return nouns[-1]
            else:
                ## return the rightmost word, just 'cause
                return np.leaves()[-1]
            
#print(examples[0])
#tree=Tree.fromstring(example)
for i in new_list[:100]:
    i=i.encode('utf-8')
    t=nlp.parse(i)
    
    examples = [str(t)]
    print(examples)
    tree=nlp.parse(sentence)
    for example in examples:
        print(example)

        tree = Tree.fromstring(example)
        for np in find_noun_phrases(tree):
       
            print(" ".join(np.leaves()))
            head = find_head_of_np(np)
            if(head not in head_word):
                print(head)
                head_word.append(head)
# Out:
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP\n      (VP (VBP charge)\n        (NP (PRP it))\n        (PP (IN at)\n          (NP (NN night))))\n      (CC and)\n      (VP (VB skip)\n        (S\n          (VP (VBG taking)\n            (NP (DT the) (NN cord))\n            (PP (IN with)\n              (NP (PRP me)))\n            (PP (IN because)\n              (PP (IN of)\n                (NP (DT the) (JJ good) (NN battery) (NN life))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP
#       (VP (VBP charge)
#         (NP (PRP it))
#         (PP (IN at)
#           (NP (NN night))))
#       (CC and)
#       (VP (VB skip)
#         (S
#           (VP (VBG taking)
#             (NP (DT the) (NN cord))
#             (PP (IN with)
#               (NP (PRP me)))
#             (PP (IN because)
#               (PP (IN of)
#                 (NP (DT the) (JJ good) (NN battery) (NN life))))))))
#     (. .)))
# I
# it
# night
# the cord
# me
# the good battery life
# ...

# %%
from nltk.corpus import wordnet

morphy_tag = {'NN':wordnet.NOUN,'NNP':wordnet.NOUN,'JJR':wordnet.ADJ,'JJS':wordnet.ADJ,'VBN':wordnet.VERB,'VBG':wordnet.VERB,'VBP':wordnet.VERB,'VBZ':wordnet.VERB,'VBD':wordnet.VERB,'RB':wordnet.ADV,'VBG':wordnet.VERB,'RBS':wordnet.ADV,'RBR':wordnet.ADV,'RBS':wordnet.ADV}



 #ADJ, ADJ_SAT, ADV, NOUN, VERB = 'a', 's', 'r', 'n', 'v'
#}
print(head_word)
# Out:
# ['I', 'it', 'night', 'cord', 'me', 'life', 'laptop', 'problems', 'computer', 'guy', 'center', 'exchange', 'concern', 'team', 'sales', 'shop', 'netbook', 'netbooks', 'NB305-N410BL', 'day', 'presentation', 'seminar', 'lots', 'conference', 'town', 'people', 'prep', 'etc.', 'projector', 'quality', 'GUI', 'applications', 'Easy', 'much', 'laptops', 'Sad', 'son', 'features', 'more', 'iChat', 'Photobooth', 'band', 'PC', 'phone', 'they', 'nothing', 'problem', 'thing', 'light', 'dark', 'money', 'while', 'Fund', 'disappointment', 'model', 'ones', 'line', 'cards', 'processor', 'trade-off', 'you', 'hours', 'Asus', 'screen', 'battery', 'MacBooks', 'enclosure', 'edge', 'seal', 'con', 'area', 'mouse', 'gaming', 'work', 'one', 'They', 'place', 'Toshiba', 'any', 'repair', 'boy', 'this', 'advantage', 'company', 'commercials', 'there', 'things', 'Apple', 'way', 'suite', 'software', 'speed', 'side', 'time', 'Windows', 'expectation', 'that', 'devices', 'game', 'here', 'No', 'keyboard', 'issue', 'everythin
# ...

# %%
len(head_word)
# Out:
# 231

# %%
from stanfordcorenlp import StanfordCoreNLP as scn
sen="the food was best but the serving was poor"
nlp=scn('/home/vibha/Downloads/stanford-corenlp-full-2018-10-05')

def get_governor_words(sen):
    check_list=['amod','nsubj','dep','dboj']
    a=nlp.dependency_parse(sen)
    print(a)
    l=[]
    for i in a:
        if i[0] in check_list:
            l.append(i[2])
    return l
get_governor_words(sen)
# Out:
# [(u'ROOT', 0, 9), (u'det', 2, 1), (u'nsubj', 9, 2), (u'cop', 9, 3), (u'advmod', 5, 4), (u'cc', 9, 5), (u'det', 7, 6), (u'nsubj', 9, 7), (u'cop', 9, 8)]
# [2, 7]

# %%
from nltk import ne_chunk, pos_tag, word_tokenize
from nltk.tree import Tree

def get_continuous_chunks(text):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    #print chunked
    continuous_chunk = []
    current_chunk = []
    for i in chunked:
        if type(i) == Tree:
            current_chunk.append(" ".join([token for token, pos in i.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue
    return continuous_chunk

#print a

# %%
from nltk import word_tokenize
from nltk.corpus import wordnet as wn
import nltk
from nltk.chunk import ne_chunk

def noun_synsets(word):
    pos_list=[]
    a=wn.synsets(word)
#     print(a)
    for synset in a:
        b=synset.lemma_names()
        b=nltk.pos_tag(b)
        
        for i in b:
            if(i[1]=='NN'):
                pos_list.append(i[0])
    return pos_list

# %%
import re
from nltk.tree import Tree
import pandas as pd

df=pd.DataFrame(columns=['word'])
df['stopword']=0
df['pos_tag']=''
df['word_len']=0

for i in new_list[:100]:
    print(i)
    sen=i
    senten=i
    sen = [re.sub(r"[^a-zA-Z0-9]+", ' ', k) for k in sen.split("\n")]
    #print(sen)
    sen2=sen
    sen=word_tokenize(sen[0])
    from nltk.corpus import stopwords
    a=set(stopwords.words('english'))
    df_new=pd.DataFrame(sen,columns=['word'])
    #print(sen)
    df_new['stopword']=0
    df_new['pos_tag']=''
    df_new['word_len']=0
    for i in range(0,len(df_new)):
        if (df_new['word'][i]) in a:
            df_new['stopword'][i]=1
        else:
            df_new['stopword'][i]=0
        if(len(df_new['word'][i])>3):
            df_new['word_len'][i]=1
        else:
            df_new['word_len'][i]=0
    
    post_tag=nltk.pos_tag(sen
                     )
    pos=[]
    #df['pos']=""

    for i in range(0,len(post_tag)):
        
        pos.append(post_tag[i][1])

    df_new['pos_tag']=pos
    
    next_l=[]
    k=0
    for i in range(0,len(sen)-1):
    #printi
        next_l.append(sen[i+1])
    next_l.append("")
    df_new['next_words']=""
    df_new['next_words']=next_l

    df_new['prev_words']=""
    prev=[]
    prev.append(""
               )
    
    for i in range(1,len(sen)):
        prev.append(sen[i-1])
    df_new['prev_words']=prev
    df_new['pre_word_tag']=""
    df_new['post_word_tag']=""
    df_new['head_word']=0
    pos_pre=[]
    pos_pre.append("")
    pos_post=[]
    
    for i in range(0,len(post_tag)-1):
        pos_post.append(post_tag[i+1][1])
    pos_post.append("")
    for i in range(1,len(post_tag)):
        pos_pre.append(post_tag[i-1][1])

    df_new['pre_word_tag']=pos_pre
    df_new['post_word_tag']=pos_post
    
        
    df_new['ortho_features']=''
    for i in range(0,len(df_new)):
        if ((df_new['word'][i].istitle() == True) or (df_new['word'][i].isdigit()==True)):
            df_new['ortho_features'][i]=1
        else:
            df_new['ortho_features'][i]=0
            
    df_new['token_freq']=''
    for i in range(0,len(df_new)):
        df_new['token_freq'][i]=sen.count(df_new['word'][i])
        
    df_new['aspect']=0
    
    for i in range(0,len(df_new)):
        if (df_new['word'][i]) in head_word:
            #['word'][i]
            df_new['head_word'][i]=1
            #df_new['aspect'][i]=1
        else:
            df_new['head_word'][i]=0
            #df_new['head_word'][i]=0
            
    df_new['head_word_tag_new']=""
    for i in range(0,len(post_tag)):
        if(post_tag[i][0] in head_word):
            df_new['head_word_tag_new'][i]=post_tag[i][1]
        
    #relation
    #for i in range(0,len(df_new)):
        #if(df_new['pos_tag'][i]=='NN'):
            #df_new['aspect'][i]
    
    df_new['lematized_words']='NULL'
    lema=[]
    from nltk.stem import WordNetLemmatizer 
  
    lemmatizer = WordNetLemmatizer() 
    for i in range(0,len(sen)):
        c=post_tag[i][1]
        for name in morphy_tag.keys():
            if name == c:
                new=morphy_tag[name]
        lema.append(lemmatizer.lemmatize(post_tag[i][0],new))
    
    df_new['lematized_words']=lema
    chunked = ne_chunk(pos_tag(word_tokenize(senten)))
    #print chunked
    continuous_chunk = []
    current_chunk = []
    for i in chunked:
        if type(i) == Tree:
            current_chunk.append(" ".join([token for token, pos in i.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue
    
    
    a=continuous_chunk
    df_new['ner']=0
    for x in a:
        df_new.loc[df_new.word==x,'ner']=1
    
    
    
    df = pd.concat([df, df_new])
print(df)
# Out:
# I charge it at night and skip taking the cord with me because of the good battery life.
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
for i in new_list2[:1]:
    sen=i
    sen = [re.sub(r"[^a-zA-Z0-9]+", ' ', k) for k in sen.split("\n")]
    #print(sen)
    sen2=sen
    sen=word_tokenize(sen[0])
    post_tag=nltk.pos_tag(sen
                     )
    df_new['head_word_tag']=""
    for i in range(0,len(post_tag)):
    
        if(post_tag[i][0] in head_word):
            df_new['head_word_tag'][i]=post_tag[i][1]

    df = pd.concat([df, df_new])
# Out:
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app

# %%
df
# Out:
#    aspect  head_word head_word_tag_new lematized_words  ner next_words  \
# 0     0.0        0.0                               The  0.0      spicy
# 1     0.0        0.0                             spicy  0.0       tuna
# 2     0.0        0.0                              tuna  0.0       roll
# 3     0.0        1.0                NN            roll  0.0        was
# 4     0.0        0.0                                be  0.0    amazing
# 5     0.0        0.0                             amaze  0.0
#
#   ortho_features pos_tag post_word_tag pre_word_tag prev_words  stopword  \
# 0              1      DT            NN                                 0
# 1              0      NN            NN           DT        The         0
# 2              0      NN            NN           NN      spicy         0
# 3              0      NN           VBD           NN       tuna         0
# 4              0     VBD           VBG           NN       roll         1
# ...

# %%
df.to_csv('ayushi_important.csv')

# %%
df=pd.read_csv("ayushi_important.csv")

# %%
df
# Out:
#             word  aspect  head_word head_word_tag_new lematized_words  ner  \
# 0              I       0          1               PRP               I    0
# 1         charge       0          0               NaN          charge    0
# 2             it       0          1               PRP              it    0
# 3             at       0          0               NaN              at    0
# 4          night       0          1                NN           night    0
# 5            and       0          0               NaN             and    0
# 6           skip       0          0               NaN            skip    0
# 7         taking       0          0               NaN            take    0
# 8            the       0          0               NaN             the    0
# 9           cord       1          1                NN            cord    0
# 10          with       0          0               NaN            with    0
# ...

# %%
y = df['aspect']
X = df.drop(['aspect'],axis=1)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.)

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB().fit(X_train, y_train)

# %%
X_test='the spicy tuna roll was amazing'

# %%
y_pred = nb.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-e6f42dbace8e> in <module>()
# ----> 1 y_pred = nb.predict(X_test)
#
# /home/vibha/miniconda2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in predict(self, X)
#      64             Predicted target values for X
#      65         """
# ---> 66         jll = self._joint_log_likelihood(X)
#      67         return self.classes_[np.argmax(jll, axis=1)]
#      68
#
# /home/vibha/miniconda2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in _joint_log_likelihood(self, X)
#     728         check_is_fitted(self, "classes_")
#     729
# --> 730         X = check_array(X, accept_sparse='csr')
#     731         return (safe_sparse_dot(X, self.feature_log_prob_.T) +
#     732                 self.class_log_prior_)
#
# ...

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.7619047619047619

# %%
cm=confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[118  33]
#  [  7  10]]

# %% [markdown]
# SVM

# %%
from sklearn import svm

# %%
model = svm.SVC(kernel='linear', C=1, gamma=1) 
# there is various option associated with it, like changing kernel, gamma and C value.Train the model using the training sets and check score
model.fit(X_train,y_train )
model.score(X_test, y_test)
#Predict Output
predicted= model.predict(X_test)

# %%
metrics.accuracy_score(y_test, predicted)
# Out:
# 0.8988095238095238

# %%
cm=confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[118  33]
#  [  7  10]]

# %%
df
# Out:
#    aspect  head_word head_word_tag_new lematized_words  ner next_words  \
# 0       0          0               NaN             The    0      spicy
# 1       0          0               NaN           spicy    0       tuna
# 2       1          0               NaN            tuna    0       roll
# 3       1          1                NN            roll    0        was
# 4       0          0               NaN              be    0    amazing
# 5       0          0               NaN           amaze    0        NaN
#
#    ortho_features pos_tag post_word_tag pre_word_tag prev_words  stopword  \
# 0               1      DT            NN          NaN        NaN         0
# 1               0      NN            NN           DT        The         0
# 2               0      NN            NN           NN      spicy         0
# 3               0      NN           VBD           NN       tuna         0
# 4               0     VBD           VBG           NN       roll         1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
df=MultiColumnLabelEncoder(columns =['word', 'aspect', 'head_word', 'head_word_tag_new', 'lematized_words', 'ner', 'next_words', 'ortho_features', 'pos_tag', 'post_word_tag', 'pre_word_tag', 'prev_words', 'stopword', 'token_freq', 'word_len']).fit_transform(df)

# %%
df=df.fillna(0)

# %%
df
# Out:
#      word  aspect  head_word  head_word_tag_new  lematized_words  ner  \
# 0      16       0          1                 10               16    0
# 1      76       0          0                  0               73    0
# 2     150       0          1                 10              140    0
# 3      55       0          0                  0               53    0
# 4     183       0          1                  7              173    0
# 5      49       0          0                  0               48    0
# 6     240       0          0                  0              228    0
# 7     254       0          0                  0              241    0
# 8     260       0          0                  0              247    0
# 9      86       1          1                  7               83    0
# 10    296       0          0                  0              278    0
# 11    170       0          1                 10              160    0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'word', 'aspect', 'head_word', 'head_word_tag_new', 'lematized_words', 'ner', 'next_words', 'ortho_features', 'pos_tag', 'post_word_tag', 'pre_word_tag', 'prev_words', 'stopword', 'token_freq', 'word_len'], dtype='object')

# %%
df
# Out:
#    aspect  head_word  head_word_tag_new  lematized_words  ner  next_words  \
# 0       0          0                  0                0    0           3
# 1       0          0                  0                4    0           4
# 2       1          0                  0                5    0           2
# 3       1          1                  1                3    0           5
# 4       0          0                  0                2    0           1
# 5       0          0                  0                1    0           0
#
#    ortho_features  pos_tag  post_word_tag  pre_word_tag  prev_words  stopword  \
# 0               1        0              1             0           0         0
# 1               0        1              1             1           1         0
# 2               0        1              1             2           3         0
# 3               0        1              2             2           4         0
# ...

# %%
import os
p=os.popen("echo '"+"I charge it at night and skip taking the cord with me because of the very good battery life"+"'~/stanford-parser-2012-11-12/stanfordtemp.txt")
print(p)
parser_out = os.popen("~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt")
print(parser_out)
    
for relation in parser_out:
        
    print(relation)
# Out:
# <open file "echo 'I charge it at night and skip taking the cord with me because of the very good battery life'~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7f1e1f606e40>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7f1e1f606db0>
# (ROOT
#
#   (S
#
#     (NP (PRP I))
#
#     (VP
#
#       (VP (VBP charge)
#
#         (NP (PRP it))
#
#         (PP (IN at)
#
#           (NP (NN night))))
#
#       (CC and)
#
#       (VP (VB skip)
#
#         (S
#
#           (VP (VBG taking)
#
#             (NP (DT the) (NN cord))
#
#             (PP (IN with)
#
#               (NP
#
#                 (NP (PRP me))
#
#                 (PP (RB because) (IN of)
#
#                   (NP (DT the)
#
#                     (ADJP (RB not) (JJ good))
#
#                     (NN battery) (NN life)))))))))))
#
#
#
# nsubj(charge-2, I-1)
#
# nsubj(skip-7, I-1)
#
# root(ROOT-0, charge-2)
#
# dobj(charge-2, it-3)
#
# ...

# %%
def get_aspects(path):
    tree=ET.parse(path)
    root = tree.getroot()
    as_f=[]
    as_final=[]
    c=0
    for review in root.findall('./sentence'):
                as_f=[]
                new=review.attrib['id']
                print(new)
                if review.find('aspectTerms'):
                    for text_string in review.findall('aspectTerms'):
                        #print(text_string)
                        a=text_string.findall('aspectTerm')
                        #print(a)
                        for i in a:
                            id=i.attrib['term']
                            am=id.split(" ")
                            for c in am:
                                as_f.append(c)
                    as_final.append(as_f)
                            #print(id)
                         #   id=s.attrib['term']
                        #print(id)
#                         for s in a:
#                             print(s)
#                             if s is not None:
#                                 id=s.attrib['term']
#                                 #print(id)
#                                 am=id.split(" ")
#                                 for c in am:
#                                     #print(c)
#                                     as_f.append(c)
#                             print(as_f)
                        #as_final.append(as_f)
                else:
                    print("no")
                    as_f=[]
                    as_final.append(as_f)
                            
                    #print("ak")
#                 if text_string is not None:
#                     id=text_string.attrib['term']
#                     print id
#                 else:
#                     id=[]
                #print(text_string)
                #print("ayushi")
                #print(am)
#                 am=am.split(" ")
#                 print(am)
#                 for i in am:
#                     as_f.append(i)
#                 as_final.append(as_f)
                
#                 text_string=""
#                 opinion_inner_list=[]
                #or sent in review.findall('./sentences/sentence'):
                #print(sent)
                #ids=review.attrib['aspec]
                #print(ids)
#                 #id_list.append(ids)
#                 for i in review.findall('aspectTerm'):
#                     print(i)
#                     am=i.attrib['term']
#                     am=am.split(" ")
                    #print(am)
                    #print("ayushi")
#                     for i in am:
#                         new_list.append(i)
    
                    

    return as_f,as_final
as_f,as_final = get_aspects("/home/ayushi/Downloads/stanford-corenlp-full-2018-10-05/Laptops_Train.xml")
# Out:
# 2339
# 812
# no
# 1316
# 2328
# no
# 2193
# no
# 2005
# 2789
# 425
# no
# 76
# 747
# no
# 80
# 796
# no
# 917
# 1788
# no
# 338
# 1630
# 38
# 337
# 1505
# no
# 263
# no
# 1227
# no
# 1019
# no
# 1158
# no
# 1168
# no
# 2568
# 295
# 951
# no
# 2759
# 2055
# no
# 2980
# 2454
# no
# 1054
# 743
# 1155
# no
# 2587
# 2202
# 2799
# no
# 2227
# 2241
# no
# 92
# 1204
# 2026
# no
# 535
# no
# 478
# no
# 1690
# no
# 1789
# no
# 250
# no
# 325
# 324
# no
# 1574
# 1005
# no
# 989
# no
# 3073
# 1254
# 810
# 1346
# no
# 2383
# no
# 130
# 1253
# no
# 839
# 1473
# no
# 782
# no
# 696
# 2878
# no
# 226
# no
# 1652
# no
# 1030
# 1425
# 2861
# no
# 661
# 997
# 192
# no
# 463
# 2866
# no
# 935
# no
# 1193
# 2192
# no
# 147
# 1433
# 1669
# 2462
# 2719
# 1224
# 588
# no
# 2492
# 1541
# 3060
# 915
# 2050
# 460
# 1954
# no
# 1728
# no
# 620
# no
# 2423
# no
# 1781
# no
# 645
# no
# 2
# no
# 1524
# 2472
# no
# 803
# 2225
# 2644
# 1365
# 1555
# no
# 2199
# no
# 72
# no
# 1151
# no
# 2033
# 2113
# no
# 2271
# ...

# %%
as_final
# Out:
# [['cord', 'battery', 'life'],
#  [],
#  ['service', 'center', '"sales"', 'team', 'tech', 'guy'],
#  [],
#  [],
#  ['quality', 'GUI', 'applications', 'use'],
#  ['start', 'up'],
#  [],
#  ['features', 'iChat', 'Photobooth', 'garage', 'band'],
#  [],
#  ['features'],
#  [],
#  ['GUI', 'screen', 'power', 'light', 'hard', 'drive', 'ligh'],
#  [],
#  ['processor', 'graphics', 'cards', 'battery', 'life'],
#  ['battery'],
#  ['rubber', 'enclosure', 'edge'],
#  ['multi-touch',
#   'gestures',
#   'tracking',
#   'area',
#   'external',
#   'mouse',
#   'gaming'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['suite', 'of', 'software'],
#  ['speed'],
#  [],
#  ['Windows', '7'],
#  [],
#  ['usb', 'devices'],
#  [],
#  ['keyboard'],
#  ['software', 'system'],
#  [],
#  ['Microsoft', 'office', 'for', 'the', 'mac'],
#  ['syncing'],
#  [],
#  ['30"', 'HD', 'Monitor', 'screen'],
#  [],
#  ['boot', 'up'],
#  ['service'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['battery'],
#  [],
# ...

# %%
aspect_term=['battery']
for p in parses:
    for governor, dep, dependent in p.triples():
        if dep=='compound':
            print("yes")
            df2['feature']=dependent[0]+'-'+governor[0]
        print(governor[0], dep, dependent[0])

# %%
as_final
# Out:
# [['cord', 'battery', 'life'],
#  [],
#  ['service', 'center', '"sales"', 'team', 'tech', 'guy'],
#  [],
#  [],
#  ['quality', 'GUI', 'applications', 'use'],
#  ['start', 'up'],
#  [],
#  ['features', 'iChat', 'Photobooth', 'garage', 'band'],
#  [],
#  ['features'],
#  [],
#  ['GUI', 'screen', 'power', 'light', 'hard', 'drive', 'ligh'],
#  [],
#  ['processor', 'graphics', 'cards', 'battery', 'life'],
#  ['battery'],
#  ['rubber', 'enclosure', 'edge'],
#  ['multi-touch',
#   'gestures',
#   'tracking',
#   'area',
#   'external',
#   'mouse',
#   'gaming'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['suite', 'of', 'software'],
#  ['speed'],
#  [],
#  ['Windows', '7'],
#  [],
#  ['usb', 'devices'],
#  [],
#  ['keyboard'],
#  ['software', 'system'],
#  [],
#  ['Microsoft', 'office', 'for', 'the', 'mac'],
#  ['syncing'],
#  [],
#  ['30"', 'HD', 'Monitor', 'screen'],
#  [],
#  ['boot', 'up'],
#  ['service'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['battery'],
#  [],
# ...

# %%
import pandas as pd
df4=pd.read_csv("/home/ayushi/Downloads/parser1.csv")

# %%
import xml.etree.ElementTree as ET
ak=[]
k=[]
c=0
path="/home/ayushi/Downloads/stanford-corenlp-full-2018-10-05/Laptops_Train.xml"
tree=ET.parse(path)
root = tree.getroot()
l=len(df4)
for i in range(0,l):
    s=df4.at[i,'VIBHA']
    x = s.replace('(',' ').replace(',',' ').replace('-',' ').replace(')',' ').split()
    print(x)
    if(x[0]!='ayushi'):
        #print x
        k.append(x)
        
    else:
        print(k)
        ak.append(k)
        k=[]
    
    
    #     if x[0]!="ayushi":
#         k.append(x)
#     ak.append(k)
# Out:
# ['nsubj', 'charge', '2', 'I', '1']
# ['root', 'ROOT', '0', 'charge', '2']
# ['dobj', 'charge', '2', 'it', '3']
# ['case', 'night', '5', 'at', '4']
# ['nmod', 'charge', '2', 'night', '5']
# ['cc', 'charge', '2', 'and', '6']
# ['conj', 'charge', '2', 'skip', '7']
# ['xcomp', 'skip', '7', 'taking', '8']
# ['det', 'cord', '10', 'the', '9']
# ['dobj', 'taking', '8', 'cord', '10']
# ['case', 'me', '12', 'with', '11']
# ['nmod', 'taking', '8', 'me', '12']
# ['case', 'life', '18', 'because', '13']
# ['mwe', 'because', '13', 'of', '14']
# ['det', 'life', '18', 'the', '15']
# ['amod', 'life', '18', 'good', '16']
# ['compound', 'life', '18', 'battery', '17']
# ['nmod', 'me', '12', 'life', '18']
# ['ayushi']
# ...

# %%
ak[5]
# Out:
# [['nsubj', 'quality', '5', 'it', '1'],
#  ['cop', 'quality', '5', 'is', '2'],
#  ['case', 'quality', '5', 'of', '3'],
#  ['amod', 'quality', '5', 'high', '4'],
#  ['root', 'ROOT', '0', 'quality', '5'],
#  ['conj', 'quality', '5', 'has', '7'],
#  ['det', 'GUI', '10', 'a', '8'],
#  ['compound', 'GUI', '10', 'killer', '9'],
#  ['dobj', 'has', '7', 'GUI', '10'],
#  ['cop', 'stable', '14', 'is', '12'],
#  ['advmod', 'stable', '14', 'extremely', '13'],
#  ['conj', 'quality', '5', 'stable', '14'],
#  ['cop', 'expandable', '18', 'is', '16'],
#  ['advmod', 'expandable', '18', 'highly', '17'],
#  ['conj', 'quality', '5', 'expandable', '18'],
#  ['auxpass', 'bundled', '21', 'is', '20'],
#  ['conj', 'quality', '5', 'bundled', '21'],
#  ['case', 'lots', '23', 'with', '22'],
#  ['nmod', 'bundled', '21', 'lots', '23'],
#  ['case', 'applications', '27', 'of', '24'],
#  ['advmod', 'good', '26', 'very', '25'],
#  ['amod', 'applications', '27', 'good', '26'],
# ...

# %%
df_final=pd.DataFrame(columns=['f','m','o'])

# %%
c=1
for i in ak:
    print i
# Out:
#   File "<ipython-input-222-2741c9176a77>", line 3
#     print i
#           ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
new_list_a=new_list[:15]

# %%
new_list_a
# Out:
# ['I charge it at night and skip taking the cord with me because of the good battery life.',
#  'I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.',
#  'The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.',
#  'I investigated netbooks and saw the Toshiba NB305-N410BL.',
#  'The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.',
#  'it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.',
#  'Easy to start up and does not overheat as much as other laptops.',
#  'Sad very SAD.',
# ...

# %%
as_final_a=as_final[:15]

# %%
as_final_a
# Out:
# [['cord', 'battery', 'life'],
#  [],
#  ['service', 'center', '"sales"', 'team', 'tech', 'guy'],
#  [],
#  [],
#  ['quality', 'GUI', 'applications', 'use'],
#  ['start', 'up'],
#  [],
#  ['features', 'iChat', 'Photobooth', 'garage', 'band'],
#  [],
#  ['features'],
#  [],
#  ['GUI', 'screen', 'power', 'light', 'hard', 'drive', 'ligh'],
#  [],
#  ['processor', 'graphics', 'cards', 'battery', 'life']]

# %%
ak
# Out:
# [[['nsubj', 'charge', '2', 'I', '1'],
#   ['root', 'ROOT', '0', 'charge', '2'],
#   ['dobj', 'charge', '2', 'it', '3'],
#   ['case', 'night', '5', 'at', '4'],
#   ['nmod', 'charge', '2', 'night', '5'],
#   ['cc', 'charge', '2', 'and', '6'],
#   ['conj', 'charge', '2', 'skip', '7'],
#   ['xcomp', 'skip', '7', 'taking', '8'],
#   ['det', 'cord', '10', 'the', '9'],
#   ['dobj', 'taking', '8', 'cord', '10'],
#   ['case', 'me', '12', 'with', '11'],
#   ['nmod', 'taking', '8', 'me', '12'],
#   ['case', 'life', '18', 'because', '13'],
#   ['mwe', 'because', '13', 'of', '14'],
#   ['det', 'life', '18', 'the', '15'],
#   ['amod', 'life', '18', 'good', '16'],
#   ['compound', 'life', '18', 'battery', '17'],
#   ['nmod', 'me', '12', 'life', '18']],
#  [['nsubj', 'bought', '3', 'I', '2'],
#   ['root', 'ROOT', '0', 'bought', '3'],
#   ['det', 'laptop', '8', 'a', '4'],
#   ['compound', 'laptop', '8', 'HP', '5'],
#   ['compound', 'laptop', '8', 'Pavilion', '6'],
# ...

# %%
# for review in root.findall('./sentence/aspectTerms'):
#                 #print(c)
#                 text_string=""
#                 opinion_inner_list=[]
#                 #or sent in review.findall('./sentences/sentence'):
#                 #print(sent)
#                 #ids=review.attrib['aspec]
#                 #print(ids)
#                 #id_list.append(ids)
#                 for i in review.findall('aspectTerm'):
#                     #print(i)
#                     am=i.attrib['term']
#                     am=am.split(" ")
#                     print(am)
#                     for i in am:
d=0
s=0
from nltk import pos_tag,word_tokenize
while((s>=0) and (s<15)):
    for k in as_final_a:
        #rint(k)
        t2=new_list_a[s]
        #print(t2)
        t2_pos=pos_tag(word_tokenize(t2))
        #print(t2_pos)
        sen=t2
        #n=0
        m=ak[s]
        print(m)
        #print("\n\n\n")
        for i in enumerate(ak[s]):
            index=i[0]
            #print(i)
            #print(index)
            #print
            
            if(i[1][0]=="dobj"):
                depen=i[1][3]
                if(depen in k):
                    #print(depen)
                    df_final.at[d,'f']=depen
                    for ele in m[:]:
                        #print(ele[0])
                        #print(ele[0])
                        if(ele[0]=="xcomp"):
                            #if(depen in as_final_a):
                            df_final.at[d,'o']=ele[1]
                            #print(sen)
                            #print(depen)
                        if(ele[0]=="amod"):
                            df_final.at[d,'o']=ele[1]
                            
                            
            if(i[1][0]=="dep"):
                gov=i[1][1]
                depen=i[1][3]
                if(depen in k):
                    df_final.at[d,'f']=depen
                    df_final.at[d,'o']=gov
                            
            if(i[1][0]=="conj"):
                depen=i[1][3]
                gov=i[1][1]
                if(gov in k):
                    df_final.at[d,'f']=gov
                    df_final.at[d,'o']=depen
                    for ele in m[:]:
                        if(ele[0]=="neg") and (ele[1]==depen):
                            df_final.at[d,'m']=ele[3]
                        if(ele[0]=="advmod") and (ele[1]==depen):
                            df_final.at[d,'m']=ele[3]
                            
            if(i[1][0]=="amod"):
                print(i[1][0])
                depen=i[1][3]
                gov=i[1][1]
                if(gov in k):
                    df_final.at[d,'f']=gov
                    df_final.at[d,'o']=depen
                    #for ele in m[:]:
         
                        
                
            if(i[1][0]=="nsubj"):
                gov=i[1][1]
                depen=i[1][3]
                #print(gov)
                #print("hj")
                #print(depen)
                if(depen in k):
                    print(gov)
                    df_final.at[d,'f']=depen
                    for ele in m[:]:
                        #print(ele[0])
                        #print(ele[0])
                        if(ele[0]=="dobj") and (ele[1]==gov):
                            print(ele[3])
                            #if(depen in as_final_a):
                            df_final.at[d,'o']=ele[3]
                        if(ele[0]=="neg") and (ele[1]==gov):
                            df_final.at[d,'m']=ele[3]
                        elif(ele[0]=="advmod") and (ele[1]==gov):
                            df_final.at[d,'m']=ele[3]
                            #print(sen)
                            #print(depen)
                    
            d=d+1
                    
                    
                    
                #print('\n\n\n')
           # if(i[0]=="dobj"):
        s=s+1
        
#                 for i+1 in ak[s]:
#                     if(j[0]=="xcomp"):
#                         print(i[1]
        #rint(sen)
#         for c in k:
#             print(c)
#             df_final.at[d,'f']=c
#             if c in t2:
#                 position=sen.index(c)
#                 for i in ak[s]:
#                     if((i[0]=='dobj') and (i[3]==c)):
#                         if(i[3]==
#                         print(i[1]+ "ayushi" + i[3])
#                         print("\n")
#         s=s+1
# d=d+1
#                 if position-2 in range(0,len(t2_pos)) and t2_pos[position-2][1]=="JJ":
#                     #print(t2_pos[position-2][0])
                    
                            #df_final.at[d,'m']=i[3]
                            
#                     #print("k")
#                     df_final.at[d,'o']=t2_pos[position-2][0]
#         #             if position-3 in range(0,len(t2_pos)) and t2_pos[position-3][1]=="RB":
#         #                 df_final.at[d,'m']=t2_pos[position-3][0]
#         #             elif position-1 in range(0,len(t2_pos)) and t2_pos[position-1][1]=="RB":
#         #                 df_final.at[d,'m']=t2_pos[position-1][0]
#                 elif position-1 in range(0,len(t2_pos)) and t2_pos[position-1][1]=="JJ":
#                     #print(t2_pos[position-1][0])
#                     for i in ak[s]:
#                         if( i[1]==t2_pos[position-1][0] and (i[0]=='advmod' or i[0]=='neg')):
#                             df_final.at[d,'m']=i[3]
#                     df_final.at[d,'o']=t2_pos[position-1][0]
#         #             if position-2 in range(0,len(t2_pos)) and t2_pos[position-2][1]=="RB":
#         #                 df_final.at[d,'m']=t2_pos[position-2][0]
#         #             elif position in range(0,len(t2_pos)) and t2_pos[position][1]=="RB":
#         #                 df_final.at[d,'m']=t2_pos[position][0]
#                 elif position+1 in range(0,len(t2_pos)) and t2_pos[position+1][1]=="JJ":
#                     #print(t2_pos[position+1][0])
#                     for i in ak[s]:
#                         if( i[1]==t2_pos[position+1][0] and (i[0]=='advmod' or i[0]=='neg')):
#                             df_final.at[d,'m']=i[3]
#                     df_final.at[d,'o']=t2_pos[position+1][0]
#         #             if position in range(0,len(t2_pos)) and t2_pos[position][1]=="RB":
#         #                 df_final.at[d,'m']=t2_pos[position][0]
#         #             elif position+2 in range(0,len(t2_pos)) and t2_pos[position+2][1]=="RB":
#         #                 df_final.at[d,'m']=t2_pos[position+2][0]
#                 elif position+2 in range(0,len(t2_pos))  and t2_pos[position+2][1]=="JJ":
#                     #print(t2_pos[position+2][0])
#                     for i in ak[s]:
#                         if(i[1]==t2_pos[position+2][0] and(i[0]=='advmod' or i[0]=='neg')):
#                             df_final.at[d,'m']=i[3]
#                     df_final.at[d,'o']=t2_pos[position+2][0]
#         #             if position+1 in range(0,len(t2_pos)) and t2_pos[position+1][1]=="RB":
#         #                 df_final.at[d,'m']=t2_pos[position+1][0]
#         #             elif position+3 in range(0,len(t2_pos)) and t2_pos[position+3][1]=="RB":
#         #                 df_final.at[d,'m']=t2_pos[position+3][0]

            
#             if((j[0]=='advmod') or (j[0]=='neg')):
#                 df_final.at[d,'m']=j[3]
        
        #print(t2)
#         for o in t2:
#             #print(o)
#             if(o[1]=='JJ'):
#                 #print(o[1])
#                 df_final.at[d,'o']=o[0]
# Out:
# [['nsubj', 'charge', '2', 'I', '1'], ['root', 'ROOT', '0', 'charge', '2'], ['dobj', 'charge', '2', 'it', '3'], ['case', 'night', '5', 'at', '4'], ['nmod', 'charge', '2', 'night', '5'], ['cc', 'charge', '2', 'and', '6'], ['conj', 'charge', '2', 'skip', '7'], ['xcomp', 'skip', '7', 'taking', '8'], ['det', 'cord', '10', 'the', '9'], ['dobj', 'taking', '8', 'cord', '10'], ['case', 'me', '12', 'with', '11'], ['nmod', 'taking', '8', 'me', '12'], ['case', 'life', '18', 'because', '13'], ['mwe', 'because', '13', 'of', '14'], ['det', 'life', '18', 'the', '15'], ['amod', 'life', '18', 'good', '16'], ['compound', 'life', '18', 'battery', '17'], ['nmod', 'me', '12', 'life', '18']]
# amod
# ...

# %%
df_final
# Out:
#                 f           m           o
# 9            cord         NaN        life
# 15           life         NaN        good
# 36            guy        then         NaN
# 41         center         not    exchange
# 56           team         NaN       sales
# 116       quality         NaN        high
# 118       quality         NaN         has
# 121           GUI         NaN        easy
# 124       quality   extremely      stable
# 127       quality      highly  expandable
# 129       quality         NaN     bundled
# 134  applications         NaN        good
# 137       quality         NaN        easy
# 143       quality  absolutely    gorgeous
# 151         start        much    overheat
# 176         iChat         NaN  Photobooth
# 178         iChat         NaN        band
# 180         iChat         NaN        more
# 201      features         NaN        many
# 202      features         NaN       great
# 203      features         NaN    features
# ...

# %%
sen='I charge it at night and skip taking the cord with me because of the good battery life'

from nltk import word_tokenize

aspect_term=['battery']

sen=sen.split(" ")
l=[]
for i in ak[0]:
    if i[1] in aspect_term or i[3] in aspect_term:
        print(i[1])
        print(i[3])
#         print(i[0]+" "+sen[i[2]-1]+" "+sen[i[1]-1])
#         df2['feature']=sen[i[2]-1]+" "+sen[i[1]-1]
# Out:
# life
# battery

# %%
ls[2]
# Out:
# ['The',
#  'tech',
#  'guy',
#  'said',
#  'service',
#  'center',
#  '1-to-1',
#  'exchange',
#  'I',
#  'direct',
#  'concern',
#  '"sales"',
#  'team,',
#  'retail',
#  'shop',
#  'I',
#  'bought',
#  'netbook']

# %%
ak[0]
# Out:
# [['nsubj', 'charge', '2', 'I', '1'],
#  ['root', 'ROOT', '0', 'charge', '2'],
#  ['dobj', 'charge', '2', 'it', '3'],
#  ['case', 'night', '5', 'at', '4'],
#  ['nmod', 'charge', '2', 'night', '5'],
#  ['cc', 'charge', '2', 'and', '6'],
#  ['conj', 'charge', '2', 'skip', '7'],
#  ['xcomp', 'skip', '7', 'taking', '8'],
#  ['det', 'cord', '10', 'the', '9'],
#  ['dobj', 'taking', '8', 'cord', '10'],
#  ['case', 'me', '12', 'with', '11'],
#  ['nmod', 'taking', '8', 'me', '12'],
#  ['case', 'life', '18', 'because', '13'],
#  ['mwe', 'because', '13', 'of', '14'],
#  ['det', 'life', '18', 'the', '15'],
#  ['amod', 'life', '18', 'good', '16'],
#  ['compound', 'life', '18', 'battery', '17'],
#  ['nmod', 'me', '12', 'life', '18']]

# %%
df2=df2.add([1,0,0])

# %%
df2
# Out:
# Empty DataFrame
# Columns: [feature, modifier, opinion]
# Index: []

# %%
import xml.etree.ElementTree as ET
import nltk

def get_list(path):
    tree=ET.parse(path)
    root = tree.getroot()
    text_list = []
    id_list=[]
    new_list=[]
    sentences_list=[]
    opinion_list = []
    for review in root.findall('sentence'):
        print(review)
        text_string=""
        opinion_inner_list=[]
        #or sent in review.findall('./sentences/sentence'):
        #print(sent)
        ids=review.attrib['id']
        print(ids)
        id_list.append(ids)
        text_string= text_string+ " "+ review.find('text').text
        new_list.append(ids)
        sentences_list.append(review.find('text').text)
#             new_list.append(sent.find('text').text)
        
#         text_list.append(text_string)
#         for opinion in review.findall('./Opinions/Opinion'):
#             opinion_dict = {
#                 opinion.get('category').replace('#','_'): opinion.get('polarity')
#             }
#             opinion_inner_list.append(opinion_dict)
#         opinion_list.append(opinion_inner_list)
    return text_list,opinion_list,new_list,sentences_list
train_text_list,train_opinion_list,new_list,sentences_list = get_list("/home/vibha/Laptops_Train.xml")
# Out:
# <Element 'sentence' at 0x7f0bfeca7d90>
# 2339
# <Element 'sentence' at 0x7f0bfeca7ed0>
# 812
# <Element 'sentence' at 0x7f0bfeca7f50>
# 1316
# <Element 'sentence' at 0x7f0bfecaf110>
# 2328
# <Element 'sentence' at 0x7f0bfecaf190>
# 2193
# <Element 'sentence' at 0x7f0bfecaf210>
# 2005
# <Element 'sentence' at 0x7f0bfecaf3d0>
# 2789
# <Element 'sentence' at 0x7f0bfecaf4d0>
# 425
# <Element 'sentence' at 0x7f0bfecaf550>
# 76
# <Element 'sentence' at 0x7f0bfec9b0d0>
# 747
# <Element 'sentence' at 0x7f0bfecaf6d0>
# 80
# <Element 'sentence' at 0x7f0bfecaf7d0>
# 796
# <Element 'sentence' at 0x7f0bfecaf850>
# 917
# <Element 'sentence' at 0x7f0bfecaf9d0>
# 1788
# <Element 'sentence' at 0x7f0bfecafa90>
# 338
# <Element 'sentence' at 0x7f0bfecafc10>
# 1630
# <Element 'sentence' at 0x7f0bfecafd10>
# 38
# <Element 'sentence' at 0x7f0bfecafe50>
# 337
# <Element 'sentence' at 0x7f0bfec41090>
# 1505
# <Element 'sentence' at 0x7f0bfec41110>
# 263
# <Element 'sentence' at 0x7f0bfec41190>
# 1227
# ...

# %%
sentences_list[1]
# Out:
# 'I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.'

# %%
def get_aspects_new(path):
    tree=ET.parse(path)
    root = tree.getroot()
    text_list = []
    id_list=[]
    new_list=[]
    sentences_list=[]
    opinion_list = []
    c=0
    for review in root.findall('./sentence/aspectTerms'):
                #print(c)
                text_string=""
                opinion_inner_list=[]
                #or sent in review.findall('./sentences/sentence'):
                #print(sent)
                #ids=review.attrib['aspec]
                #print(ids)
                #id_list.append(ids)
                for i in review.findall('aspectTerm'):
                    #print(i)
                    am=i.attrib['term']
                    am=am.split(" ")
                    print(am)
                    for i in am:
                        new_list.append(i)
    
                    

    return new_list
aspect_list = get_aspects_new("/home/vibha/Laptops_Train.xml")
# Out:
# ['cord']
# ['battery', 'life']
# ['service', 'center']
# ['"sales"', 'team']
# ['tech', 'guy']
# ['quality']
# ['GUI']
# ['applications']
# ['use']
# ['start', 'up']
# ['features']
# ['iChat']
# ['Photobooth']
# ['garage', 'band']
# ['features']
# ['GUI']
# ['screen']
# ['power', 'light']
# ['hard', 'drive', 'ligh']
# ['processor']
# ['graphics', 'cards']
# ['battery', 'life']
# ['battery']
# ['rubber', 'enclosure']
# ['edge']
# ['multi-touch', 'gestures']
# ['tracking', 'area']
# ['external', 'mouse']
# ['gaming']
# ['suite', 'of', 'software']
# ['speed']
# ['Windows', '7']
# ['usb', 'devices']
# ['keyboard']
# ['software']
# ['system']
# ['Microsoft', 'office', 'for', 'the', 'mac']
# ['syncing']
# ['30"', 'HD', 'Monitor']
# ['screen']
# ['boot', 'up']
# ['service']
# ['battery']
# ['operating', 'system']
# ['preloaded', 'software']
# ['price']
# ['features']
# ['clock', 'in', 'BIOS', 'setup']
# ['WARRANTY', 'SERVICE']
# ['brand']
# ['warranty']
# ['features']
# ['fan']
# ...

# %%
aspect_list
# Out:
# ['cord',
#  'battery',
#  'life',
#  'service',
#  'center',
#  '"sales"',
#  'team',
#  'tech',
#  'guy',
#  'quality',
#  'GUI',
#  'applications',
#  'use',
#  'start',
#  'up',
#  'features',
#  'iChat',
#  'Photobooth',
#  'garage',
#  'band',
#  'features',
#  'GUI',
#  'screen',
#  'power',
#  'light',
#  'hard',
#  'drive',
#  'ligh',
#  'processor',
#  'graphics',
#  'cards',
#  'battery',
#  'life',
#  'battery',
#  'rubber',
#  'enclosure',
#  'edge',
#  'multi-touch',
#  'gestures',
#  'tracking',
#  'area',
#  'external',
#  'mouse',
#  'gaming',
#  'suite',
#  'of',
#  'software',
#  'speed',
#  'Windows',
#  '7',
#  'usb',
#  'devices',
#  'keyboard',
#  'software',
#  'system',
#  'Microsoft',
#  'office',
#  'for',
#  'the',
#  'mac',
#  'syncing',
#  '30"',
#  'HD',
#  'Monitor',
#  'screen',
#  'boot',
#  'up',
#  'service',
#  'battery',
#  'operating',
#  'system',
#  'preloaded',
#  'software',
#  'price',
#  'features',
#  'clock',
#  'in',
#  'BIOS',
# ...

# %%
import pandas as pd
df2=pd.DataFrame(columns=['f','m','o'])

from nltk import word_tokenize,pos_tag

# %%
sen=word_tokenize(sen)
sen=pos_tag(sen)
print(sen)
# Out:
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('recommend', 'VB'), ('this', 'DT'), ('product', 'NN')]

# %%
d=0

for term in sen2:
    if term in aspect_list:
        df2.at[d,'f']=term

        for word in sen:

            if word[1]=='JJ' or word[1]=='JJR' or word[1]=='JJS':
                l=l.append(word[0])
                df2.at[d,'o']=l
                l=[]
            elif word[1]=='VB':
                df2.at[d,'o']=word[0]
            if word[1]=='RB':
                df2.at[d,'m']=word[0]
        d=d+1

# %% [markdown]
# ##

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
a_new=[]
for i in aspect_list:
    if i not in stop_words:
        a_new.append(i)

# %%
a_new
# Out:
# ['cord',
#  'battery',
#  'life',
#  'service',
#  'center',
#  '"sales"',
#  'team',
#  'tech',
#  'guy',
#  'quality',
#  'GUI',
#  'applications',
#  'use',
#  'start',
#  'features',
#  'iChat',
#  'Photobooth',
#  'garage',
#  'band',
#  'features',
#  'GUI',
#  'screen',
#  'power',
#  'light',
#  'hard',
#  'drive',
#  'ligh',
#  'processor',
#  'graphics',
#  'cards',
#  'battery',
#  'life',
#  'battery',
#  'rubber',
#  'enclosure',
#  'edge',
#  'multi-touch',
#  'gestures',
#  'tracking',
#  'area',
#  'external',
#  'mouse',
#  'gaming',
#  'suite',
#  'software',
#  'speed',
#  'Windows',
#  '7',
#  'usb',
#  'devices',
#  'keyboard',
#  'software',
#  'system',
#  'Microsoft',
#  'office',
#  'mac',
#  'syncing',
#  '30"',
#  'HD',
#  'Monitor',
#  'screen',
#  'boot',
#  'service',
#  'battery',
#  'operating',
#  'system',
#  'preloaded',
#  'software',
#  'price',
#  'features',
#  'clock',
#  'BIOS',
#  'setup',
#  'WARRANTY',
#  'SERVICE',
#  'brand',
# ...

# %%
df2.at[d,'f']=term

# %%
import pandas as pd
df2=pd.DataFrame(columns=['f','m','o'])

from nltk import word_tokenize,pos_tag

# %%
d=0
l=[]
for sen in sentences_list[0:1]:
    sen2=sen
    sen=word_tokenize(sen2)
    sen=pos_tag(sen)
    print(sen)
    for term in sen:
        if term[0] in a_new:
            #print term[0]+"hello"
            
            df2.at[d,'f']=term[0]
            l=[]
            for word in sen:
                #print word
                if word[1]=='JJ' or word[1]=='JJR' or word[1]=='JJ':
                    df2.at[d,'o']=word[0]
                elif word[1]=='VB':
                    df2.at[d,'o']=word[0]
                if word[1]=='RB':
                    l.append(word[0])
            print(l)
            df2.at[d,'m']=l
            d=d+1
# Out:
# [('I', 'PRP'), ('charge', 'VBP'), ('it', 'PRP'), ('at', 'IN'), ('night', 'NN'), ('and', 'CC'), ('skip', 'NN'), ('taking', 'VBG'), ('the', 'DT'), ('cord', 'NN'), ('with', 'IN'), ('me', 'PRP'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('battery', 'NN'), ('life', 'NN'), ('.', '.')]
# []
# []
# []
# []

# %%
df2
# Out:
#          f   m     o
# 0   charge  []  good
# 1     cord  []  good
# 2  battery  []  good
# 3     life  []  good
